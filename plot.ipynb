# %%
import pandas as pd
import seaborn as sns
import glob

# %%
# load results csv
data = pd.DataFrame()
results_files = glob.glob("./eval/**/sequencies_errors.csv", recursive=True)
for result_file in results_files:
    method = os.path.dirname(result_file).split('/')[-1]
    method = method.replace("_", " ").title()
    file_data = pd.read_csv(result_file)
    file_data['Method'] = method
    data = pd.concat([data, file_data])

data = data.drop(columns=["Unnamed: 0", "mse_frame_error_29"])
data.sample(10)
# Out:
#    Sequence  mse_frame_error_0  mse_frame_error_1  mse_frame_error_2  \
# 5       5.0           0.449391           0.243634           0.068214
# 5       5.0           0.469158           0.173401           0.074329
# 7       7.0           0.213229           0.250253           0.057319
# 7       7.0           0.372808           0.324023           0.069247
# 6       6.0           0.001762           0.001536           0.001906
# 2       2.0           3.456239           2.655407           3.376634
# 7       7.0           0.676059           0.342498           0.082665
# 3       3.0           0.006908           0.006909           0.007311
# 5       5.0           0.661543           0.396991           0.053371
# 0       0.0           0.025229           0.025683           0.022855
#
#    mse_frame_error_3  mse_frame_error_4  mse_frame_error_5  mse_frame_error_6  \
# 5           0.037371           0.045016           0.049144           0.057927
# 5           0.057637           0.042180           0.026855           0.025840
# 7           0.015813           0.011141           0.007430           0.004970
# 7           0.027692           0.019015           0.012314           0.010755
# 6           0.002633           0.002603           0.003404           0.003537
# 2           6.880281          12.406593          16.620718          18.797932
# 7           0.066531           0.033748           0.019715           0.024522
# 3           0.008347           0.010068           0.011528           0.014354
# 5           0.029064           0.033169           0.027970           0.022646
# 0           0.019894           0.017124           0.014650           0.013435
#
#    mse_frame_error_7  mse_frame_error_8  ...  mse_frame_error_21  \
# 5           0.064432           0.063457  ...            0.066213
# 5           0.026790           0.026206  ...            0.095154
# 7           0.002733           0.002696  ...            0.001459
# 7           0.011405           0.011549  ...            0.007645
# 6           0.003691           0.003762  ...            0.080919
# 2          26.329706          14.366726  ...            9.082007
# 7           0.039887           0.041223  ...            0.276766
# 3           0.022400           0.037309  ...            0.936289
# 5           0.027007           0.028736  ...            0.021915
# 0           0.013198           0.013289  ...            0.233782
#
#    mse_frame_error_22  mse_frame_error_23  mse_frame_error_24  \
# 5            0.066266            0.064818            0.064998
# 5            0.101231            0.105617            0.113143
# 7            0.001480            0.001399            0.001331
# 7            0.008364            0.008930            0.009451
# 6            0.088601            0.101943            0.162634
# 2           10.385613           11.757588           12.998266
# 7            0.527830            0.897612            1.329654
# 3            0.990745            1.125334            1.012262
# 5            0.019702            0.018553            0.020146
# 0            0.416488            0.584279            0.939015
#
#    mse_frame_error_25  mse_frame_error_26  mse_frame_error_27  \
# 5            0.065556            0.066558            0.069578
# 5            0.121869            0.130823            0.137939
# 7            0.001316            0.001401            0.001702
# 7            0.010218            0.011186            0.011809
# 6            0.245901            0.127700            0.019506
# 2           13.975027           14.598330           14.886904
# 7            1.724445            2.008875            2.168930
# 3            0.806200            0.798282            1.485966
# 5            0.024923            0.031990            0.043527
# 0            1.739773            2.905818            3.634892
#
#    mse_frame_error_28  mse_frame_error_avg                Method
# 5            0.080258             0.248434           6D Weighted
# 5            0.147232             0.254783            Positional
# 7            0.002211             0.253020           6D Weighted
# 7            0.011519             0.267864            Positional
# 6            0.046497             0.251604           6D Weighted
# 2           14.931444            11.789620  Quaternions Weighted
# 7            2.231955             0.671827           Quaternions
# 3            2.103411             0.599961                 Euler
# 5            0.067068             0.229066                 Euler
# 0            3.494056             0.492023                 Euler
#
# [10 rows x 32 columns]

# %%
means_by_method = data.groupby(['Method'], as_index=False).mean()
means_by_method = means_by_method.drop(columns=['Sequence'])

# %%
means_by_method.to_csv("./eval/avg.csv")
